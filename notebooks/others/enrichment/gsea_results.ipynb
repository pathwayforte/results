# %% [markdown]
# # Plot existing versus expected equivalent pathway mappings from GSEA results

# %%
import os
import collections
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import itertools as itt

from bio2bel_kegg import Manager as KeggManager
from bio2bel_reactome import Manager as ReactomeManager
from bio2bel_wikipathways import Manager as WikipathwaysManager

from pathway_forte.constants import *
from pathway_forte.pathway_enrichment.functional_class import *

# %%
# Initiate Bio2BEL manager to map Pathway identifiers to names
kegg_manager = KeggManager()
reactome_manager = ReactomeManager()
wikipathways_manager = WikipathwaysManager()

# %%
brca_dataset = 'brca'
kirc_dataset = 'kirc'
lihc_dataset = 'lihc'
prad_dataset = 'prad'

# %% [markdown]
# Load GSEA results

# %%
brca_kegg_df, brca_reactome_df, brca_wp_df, brca_merge_df, brca_merge_total_df = gsea_results_to_filtered_df(
    brca_dataset,
    kegg_manager=kegg_manager,
    reactome_manager=reactome_manager,
    wikipathways_manager=wikipathways_manager,
    p_value=0.05,
    absolute_nes_filter=2,
    geneset_set_filter_minimum_size=10,
    geneset_set_filter_maximum_size=None
)

kirc_kegg_df, kirc_reactome_df, kirc_wp_df, kirc_merge_df, kirc_merge_total_df = gsea_results_to_filtered_df(
    kirc_dataset,
    kegg_manager=kegg_manager,
    reactome_manager=reactome_manager,
    wikipathways_manager=wikipathways_manager,
    p_value=0.05,
    absolute_nes_filter=2,
    geneset_set_filter_minimum_size=10,
    geneset_set_filter_maximum_size=None
)

lihc_kegg_df, lihc_reactome_df, lihc_wp_df, lihc_merge_df, lihc_merge_total_df = gsea_results_to_filtered_df(
    lihc_dataset,
    kegg_manager=kegg_manager,
    reactome_manager=reactome_manager,
    wikipathways_manager=wikipathways_manager,
    p_value=0.05,
    absolute_nes_filter=2,
    geneset_set_filter_minimum_size=10,
    geneset_set_filter_maximum_size=None
)

prad_kegg_df, prad_reactome_df, prad_wp_df, prad_merge_df, prad_merge_total_df = gsea_results_to_filtered_df(
    prad_dataset,
    kegg_manager=kegg_manager,
    reactome_manager=reactome_manager,
    wikipathways_manager=wikipathways_manager,
    p_value=0.05,
    absolute_nes_filter=2,
    geneset_set_filter_minimum_size=10,
    geneset_set_filter_maximum_size=None
)

# %%
lihc_merge_df
# Out:
#                                           pathway_name  \
# 0            Retinol metabolism - Homo sapiens (human)
# 1                                 Tamoxifen metabolism
# 2             Complement cascade|Complement Activation
# 3          Histidine metabolism - Homo sapiens (human)
# 4                              Human Complement System
# 5                                          Xenobiotics
# 6    Complement and coagulation cascades - Homo sap...
# 7          Parkin-Ubiquitin Proteasomal System pathway
# 8                           G1 to S cell cycle control
# 9    Transport of Mature mRNA derived from an Intro...
# 10   Cooperation of PDCL (PhLP1) and TRiC/CCT in G-...
# 11                                   Signalling to RAS
# 12                               DNA strand elongation
# 13                           Apoptotic execution phase
# 14   Mitophagy - animal - Homo sapiens (human)|Mito...
# 15    Insulin signaling pathway - Homo sapiens (human)
# 16                                 Signaling by NOTCH3
# 17   Follicle Stimulating Hormone (FSH) signaling p...
# 18        APC/C:Cdc20 mediated degradation of Cyclin B
# 19        Negative regulators of DDX58/IFIH1 signaling
# 20                                Protein localization
# 21                     Interleukin-12 family signaling
# 22                  Shigellosis - Homo sapiens (human)
# 23    TP53 Regulates Transcription of Cell Cycle Genes
# 24                      Pink/Parkin Mediated Mitophagy
# 25   Anchoring of the basal body to the plasma memb...
# 26                       Rab regulation of trafficking
# 27                     PKMTs methylate histone lysines
# 28   Major pathway of rRNA processing in the nucleo...
# 29                            Lagging Strand Synthesis
# ..                                                 ...
# 424                             Cell Cycle Checkpoints
# 425                   Nonalcoholic fatty liver disease
# 426                                    tRNA processing
# 427                                 Infectious disease
# 428  Regulation of mRNA stability by proteins that ...
# 429                                            Disease
# 430                       Cellular responses to stress
# 431                 Spliceosome - Homo sapiens (human)
# 432                        Regulation of TP53 Activity
# 433                            Dual incision in TC-NER
# 434             ABC-family proteins mediated transport
# 435  Notch signaling pathway - Homo sapiens (human)...
# 436  Protein processing in endoplasmic reticulum - ...
# 437                            Interleukin-1 signaling
# 438             Cellular responses to external stimuli
# 439                     IRE1alpha activates chaperones
# 440                                      HIV Infection
# 441  Global Genome Nucleotide Excision Repair (GG-NER)
# 442                  XBP1(S) activates chaperone genes
# 443                    Unfolded Protein Response (UPR)
# 444  Transcription-Coupled Nucleotide Excision Repa...
# 445                                   Deubiquitination
# 446                                  Metabolism of RNA
# 447            Post-translational protein modification
# 448                                         DNA Repair
# 449  Nucleotide excision repair - Homo sapiens (hum...
# 450  Pyrimidine metabolism - Homo sapiens (human)|P...
# 451                                        Neddylation
# 452                 Transcriptional Regulation by TP53
# 453                             Metabolism of proteins
#
#                             pathway_id        es       nes      pval  \
# 0                             hsa00830  0.675921  2.230719  0.000000
# 1                                WP691  0.808853  2.100633  0.001385
# 2                   R-HSA-166658|WP545  0.677238  2.078727  0.006983
# 3                             hsa00340  0.725864  2.077178  0.003989
# 4                               WP2806  0.567516  2.046771  0.000000
# 5                         R-HSA-211981  0.712671  2.040787  0.004178
# 6                       hsa04610|WP558  0.658520  2.028936  0.001244
# 7                               WP2359 -0.608084 -2.001458  0.000000
# 8                                 WP45 -0.665122 -2.001925  0.002378
# 9                         R-HSA-159236 -0.718337 -2.002650  0.000000
# 10                       R-HSA-6814122 -0.605896 -2.003563  0.003315
# 11                        R-HSA-167044 -0.689182 -2.003568  0.000000
# 12                         R-HSA-69190 -0.841401 -2.005491  0.000000
# 13                         R-HSA-75153 -0.624897 -2.005739  0.000000
# 14              hsa04137|R-HSA-5205647 -0.574563 -2.006887  0.001218
# 15                            hsa04910 -0.506275 -2.007319  0.000000
# 16                       R-HSA-9012852 -0.615287 -2.008570  0.000000
# 17                              WP2035 -0.631063 -2.011643  0.000000
# 18                        R-HSA-174048 -0.762784 -2.012243  0.000000
# 19                        R-HSA-936440 -0.642538 -2.013298  0.001218
# 20                       R-HSA-9609507 -0.511301 -2.013718  0.002421
# 21                        R-HSA-447115 -0.592074 -2.014035  0.000000
# 22                            hsa05131 -0.632844 -2.014232  0.000000
# 23                       R-HSA-6791312 -0.664963 -2.015546  0.000000
# 24                       R-HSA-5205685 -0.680698 -2.016733  0.000000
# 424  0.000000           274           273
# 425  0.000000           159           149
# 426  0.000000           108           108
# 427  0.000000           382           380
# 428  0.000000            87            87
# 429  0.000000          1064          1057
# 430  0.000000           400           399
# 431  0.000000           134           134
# 432  0.000000           160           160
# 433  0.000000            65            65
# 434  0.000000           103           103
# 435  0.000000           240           239
# 436  0.000000           165           163
# 437  0.000000           102           102
# 438  0.000000           477           475
# 439  0.000000            57            56
# 440  0.000000           234           232
# 441  0.000000            84            84
# 442  0.000000            55            54
# 443  0.000000            95            94
# 444  0.000000            78            78
# 445  0.000000           282           265
# 446  0.000000           667           665
# 447  0.000000          1404          1381
# 448  0.000000           295           295
# 449  0.000000           114           113
# 450  0.000000           102           100
# 451  0.000000           235           233
# 452  0.000000           365           360
# 453  0.000000          1998          1971
#
#                                                  genes  \
# 0    CYP2C8;CYP4A11;LRAT;CYP4A22;ADH4;RDH16;UGT2B7;...
# 1    CYP2C8;UGT2B7;CYP2C9;CYP1A2;CYP2C19;CYP2E1;SUL...
# 2    FCN2;COLEC10;CFP;FCN3;C1R;C8A;C6;C9;C8B;MASP1;...
# 3    ALDH2;CNDP1;UROC1;ASPA;FTCD;AMDHD1;ALDH1B1;MAO...
# 4    FCN2;CLEC4M;CFP;C1R;C8A;C6;ALB;C9;PLG;MASP1;KL...
# 5    CYP2C8;CYP2C9;CYP1A2;CYP2B6;CYP2J2;CYP2C19;CYP...
# 6    C1R;C8A;C6;C9;PLG;C8B;MASP1;F9;KLKB1;C1S;FGB;S...
# 7    TUBB1;UBE2L6;SNCA;CASP1;HSPA6;UBE2G1;TUBB6;GPR...
# 8    WEE1;MYC;GADD45A;CREB3L3;CDKN1A;CCND1;CCNA1;CC...
# 9    CDC40;SRSF5;NUP88;FYTTD1;RANBP2;NUP98;U2AF1;NU...
# 10   GNAO1;CCT6B;RGS7;GNB4;GNG2;GNAT2;GNGT2;GNG12;R...
# 11   NGF;RALGDS;NTRK1;KRAS;SHC2;RALB;MAPK13;SOS1;SH...
# 12   POLD2;POLD4;GINS4;RPA1;POLD3;RPA3;RPA2;DNA2;MC...
# 13   TJP2;SATB1;BMX;DSG1;CASP7;DSG3;PRKCQ;PKP1;CDH1...
# 14   JUN;GABARAPL1;PINK1;CITED2;TBC1D15;BNIP3L;MFN2...
# 15   GYS2;FBP1;PCK1;SOCS2;FOXO1;PCK2;PPP1R3B;MAP2K1...
# 16   HEY2;HES1;PTCRA;KAT2B;IKZF1;EGFR;FABP7;PBX1;ST...
# 17   FOXO1;SGK1;FSHR;FSHB;AREG;AKT1;BDNF;CGA;CYP19A...
# 18   UBB;ANAPC16;CDC26;ANAPC10;UBC;UBE2D1;UBA52;RPS...
# 19   RNF125;HERC5;ISG15;ITCH;UBE2L6;IFIH1;DDX58;RNF...
# 20   HAO2;HAO1;ACAA1;EPHX2;HMGCL;MLYCD;LDHD;CAT;FXN...
# 21   IL6ST;IL27;IL10;GSTA2;STAT3;EBI3;SOD1;SOD2;SER...
# 22   HCLS1;NFKBIA;CRK;CXCL8;PFN3;U2AF1L5;NFKB1;MAPK...
# 450  POLR2J;POLD2;POLR2I;AK9;NT5C3A;POLD4;RRM2B;TWI...
# 451  COMMD9;ASB7;DCAF5;DCAF10;PSMB6;FEM1A;FBXO31;KL...
# 452  BRD1;NDRG1;CNOT1;GSR;CDKN1B;LAMTOR3;ING2;CREBB...
# 453  COMMD9;RPL34;F5;MAN2A1;EP300;ASB7;MIA3;PIGA;NA...
#
# [454 rows x 10 columns]

# %% [markdown]
# Load mappings and create mapping dictionary

# %%
brca_actual_dict, brca_expected_dict = get_pairwise_mapping_numbers(
    brca_kegg_df, 
    brca_reactome_df, 
    brca_wp_df, 
    brca_merge_df, 
    brca_merge_total_df
)
kirc_actual_dict, kirc_expected_dict = get_pairwise_mapping_numbers(
    kirc_kegg_df, 
    kirc_reactome_df, 
    kirc_wp_df, 
    kirc_merge_df, 
    kirc_merge_total_df
)
lihc_actual_dict, lihc_expected_dict = get_pairwise_mapping_numbers(
    lihc_kegg_df, 
    lihc_reactome_df, 
    lihc_wp_df, 
    lihc_merge_df, 
    lihc_merge_total_df
)
prad_actual_dict, prad_expected_dict = get_pairwise_mapping_numbers(
    prad_kegg_df, 
    prad_reactome_df, 
    prad_wp_df, 
    prad_merge_df, 
    prad_merge_total_df
)

# %%
brca_kegg_df.head()
# Out:
#                                         pathway_name pathway_id        es  \
# 0  Drug metabolism - cytochrome P450 - Homo sapie...   hsa00982  0.606361
# 1          Retinol metabolism - Homo sapiens (human)   hsa00830  0.542550
# 2     Chemical carcinogenesis - Homo sapiens (human)   hsa05204  0.525088
# 3  Regulation of lipolysis in adipocytes - Homo s...   hsa04923  0.661784
# 4             Renin secretion - Homo sapiens (human)   hsa04924  0.570864
#
#         nes  pval       fdr  geneset_size  matched_size  \
# 0  2.392575   0.0  0.007270            70            67
# 1  2.181489   0.0  0.023627            67            64
# 2  2.178827   0.0  0.015751            82            78
# 3  2.165316   0.0  0.011813            54            54
# 4  2.091903   0.0  0.028352            65            65
#
#                                                genes  \
# 0  FMO2;ADH5;ADH1C;MAOA;ADH1B;GSTM2;ADH4;ADH1A;AL...
# 1  ALDH1A2;ADH5;ADH1C;ALDH1A1;RDH5;ADH1B;RETSAT;A...
# 2  ADH5;ADH1C;ADH1B;GSTM2;ADH4;ADH1A;ALDH1A3;HSD1...
# 3  ADRB2;ADCY4;PIK3R1;NPR1;GNAI1;PLIN1;FABP4;LIPE...
# 4  ADRB2;AQP1;PDE1C;PTGER4;NPR1;GNAI1;ADCYAP1R1;C...
#
#                                          ledge_genes
# 0  FMO2;ADH5;ADH1C;MAOA;ADH1B;GSTM2;ADH4;ADH1A;AL...
# 1  ALDH1A2;ADH5;ADH1C;ALDH1A1;RDH5;ADH1B;RETSAT;A...
# 2  ADH5;ADH1C;ADH1B;GSTM2;ADH4;ADH1A;ALDH1A3;HSD1...
# 3  ADRB2;ADCY4;PIK3R1;NPR1;GNAI1;PLIN1;FABP4;LIPE...
# 4  ADRB2;AQP1;PDE1C;PTGER4;NPR1;GNAI1;ADCYAP1R1;C...

# %%
brca_reactome_df.head()
# Out:
#                                pathway_name     pathway_id        es  \
# 0  Phase I - Functionalization of compounds   R-HSA-211945  0.581830
# 1       FGFR2 ligand binding and activation   R-HSA-190241  0.698974
# 2       FGFR1 ligand binding and activation   R-HSA-190242  0.717446
# 3   Phospholipase C-mediated cascade: FGFR1  R-HSA-5654219  0.718803
# 4                       PI-3K cascade:FGFR1  R-HSA-5654689  0.686072
#
#         nes      pval       fdr  geneset_size  matched_size  \
# 0  2.352063  0.000000  0.007433           105           105
# 1  2.338042  0.000000  0.004392            20            20
# 2  2.335312  0.000000  0.003153            16            16
# 3  2.329780  0.000000  0.002365            16            16
# 4  2.324603  0.002092  0.002027            21            21
#
#                                                genes  \
# 0  CYP2U1;FMO2;ADH5;ADH1C;ALDH1A1;CES2;AOC3;CYP11...
# 1  FGF1;FGF2;FGF7;FGF17;FGFBP2;FGF16;FGF8;FGF20;F...
# 2  FGF1;KL;FGF2;FGF17;FGFR1;FGF8;FGF20;FGF9;FGF6;...
# 3  FGF1;KL;FGF2;FGF17;FGFR1;FGF8;FGF20;FGF9;FGF6;...
# 4  FGF1;KL;PIK3R1;FGF2;PTPN11;FGF17;GAB1;FGFR1;PI...
#
#                                          ledge_genes
# 0  CYP2U1;FMO2;ADH5;ADH1C;ALDH1A1;CES2;AOC3;CYP11...
# 1  FGF1;FGF2;FGF7;FGF17;FGFBP2;FGF16;FGF8;FGF20;FGF9
# 2           FGF1;KL;FGF2;FGF17;FGFR1;FGF8;FGF20;FGF9
# 3           FGF1;KL;FGF2;FGF17;FGFR1;FGF8;FGF20;FGF9
# 4  FGF1;KL;PIK3R1;FGF2;PTPN11;FGF17;GAB1;FGFR1;PI...

# %%
brca_wp_df.head()
# Out:
#                               pathway_name pathway_id        es       nes  \
# 0  Phosphodiesterases in neuronal function     WP4222  0.617845  2.200640
# 1             GPCRs, Class B Secretin-like      WP334  0.684921  2.192811
# 2               Fatty Acid Omega Oxidation      WP206  0.832027  2.125292
# 3         Melatonin metabolism and effects     WP3298  0.594248  2.100261
# 4                ESC Pluripotency Pathways     WP3931  0.504015  2.086433
#
#        pval       fdr  geneset_size  matched_size  \
# 0  0.000000  0.021374            53            53
# 1  0.000000  0.014249            24            24
# 2  0.000000  0.023749            15            15
# 3  0.005882  0.024936            42            38
# 4  0.000000  0.027073           118           116
#
#                                                genes  \
# 0  PDE2A;ADCY4;PDE1C;PDE7B;GRIN2B;PDE1A;PDE3B;PDE...
# 1  ADGRL4;ADCYAP1R1;SCTR;VIPR1;CRHR2;ADGRL2;ADGRL...
# 2  ADH1C;ALDH1A1;ADH1B;ALDH2;ADH4;ADH1A;ADH6;CYP3...
# 3  FOXO1;CRY2;PER1;PER2;MAOA;PER3;TRAF6;EDN1;SIRT...
# 4  LIFR;FGF1;SELENOP;FGF2;SMAD9;FGF7;FZD4;PDGFRA;...
#
#                                          ledge_genes
# 0  PDE2A;ADCY4;PDE1C;PDE7B;GRIN2B;PDE1A;PDE3B;PDE...
# 1  ADGRL4;ADCYAP1R1;SCTR;VIPR1;CRHR2;ADGRL2;ADGRL...
# 2  ADH1C;ALDH1A1;ADH1B;ALDH2;ADH4;ADH1A;ADH6;CYP3...
# 3  FOXO1;CRY2;PER1;PER2;MAOA;PER3;TRAF6;EDN1;SIRT...
# 4  LIFR;FGF1;SELENOP;FGF2;SMAD9;FGF7;FZD4;PDGFRA;...

# %%
brca_merge_df
# Out:
#                                           pathway_name  \
# 0    Drug metabolism - cytochrome P450 - Homo sapie...
# 1             Phase I - Functionalization of compounds
# 2                  FGFR2 ligand binding and activation
# 3                                  PI-3K cascade:FGFR2
# 4              Phospholipase C-mediated cascade; FGFR2
# 5                     Activated point mutants of FGFR2
# 6              Phospholipase C-mediated cascade: FGFR1
# 7                  FGFR1 ligand binding and activation
# 8              Phosphodiesterases in neuronal function
# 9                                  PI-3K cascade:FGFR1
# 10                                 PI-3K cascade:FGFR4
# 11                                  Signaling by FGFR1
# 12                 Interaction between L1 and Ankyrins
# 13             Phospholipase C-mediated cascade; FGFR4
# 14           Retinol metabolism - Homo sapiens (human)
# 15           Nitric oxide stimulates guanylate cyclase
# 16   NOTCH4 Intracellular Domain Regulates Transcri...
# 17      Chemical carcinogenesis - Homo sapiens (human)
# 18   Regulation of lipolysis in adipocytes - Homo s...
# 19                                        cGMP effects
# 20                      Phase 0 - rapid depolarisation
# 21              Genes targeted by miRNAs in adipocytes
# 22             Downstream signaling of activated FGFR1
# 23              Prostaglandin Synthesis and Regulation
# 24                          Fatty Acid Omega Oxidation
# 25                                  Muscle contraction
# 26   Synthesis of bile acids and bile salts via 27-...
# 27           Morphine addiction - Homo sapiens (human)
# 28                    Melatonin metabolism and effects
# 29       Fatty acid degradation - Homo sapiens (human)
# ..                                                 ...
# 339  DNA replication - Homo sapiens (human)|DNA Rep...
# 340                                    G2/M Transition
# 341                             Mitotic G2-G2/M phases
# 342           Transcriptional regulation by small RNAs
# 343                               Mitotic Prometaphase
# 344                              Gene Silencing by RNA
# 345                                    UCH proteinases
# 346           Epigenetic regulation of gene expression
# 347  Homologous recombination - Homo sapiens (human...
# 348                    Separation of Sister Chromatids
# 349                             Protein ubiquitination
# 350                             Chromosome Maintenance
# 351         HDR through Homologous Recombination (HRR)
# 352                                   Mitotic Anaphase
# 353                     Mitotic Metaphase and Anaphase
# 354                         G2/M DNA damage checkpoint
# 355                                      HIV Infection
# 356                   Host Interactions of HIV factors
# 357                                   Mitotic Prophase
# 358         Processing of DNA double-strand break ends
# 359                                Cell Cycle, Mitotic
# 360                             Cell Cycle Checkpoints
# 361  Cell cycle - Homo sapiens (human)|Cell Cycle|C...
# 362                     DNA Double-Strand Break Repair
# 363                                   G2/M Checkpoints
# 364      COPI-dependent Golgi-to-ER retrograde traffic
# 365                                            M Phase
# 366                           Homology Directed Repair
# 367                                         DNA Repair
# 368  HDR through Homologous Recombination (HRR) or ...
#
#                        pathway_id        es       nes      pval       fdr  \
# 0                        hsa00982  0.606361  2.386178  0.000000  0.007034
# 1                    R-HSA-211945  0.581830  2.362068  0.000000  0.005140
# 2                    R-HSA-190241  0.698974  2.333409  0.000000  0.006132
# 356                  R-HSA-162909 -0.744201 -2.415909  0.000000  0.000000
# 357                   R-HSA-68875 -0.680851 -2.416217  0.000000  0.000000
# 358                 R-HSA-5693607 -0.731543 -2.456606  0.000000  0.000000
# 359                   R-HSA-69278 -0.691102 -2.472545  0.000000  0.000000
# 360                   R-HSA-69620 -0.748644 -2.491161  0.000000  0.000000
# 361  hsa04110|R-HSA-1640170|WP179 -0.673898 -2.498249  0.000000  0.000000
# 362                 R-HSA-5693532 -0.702482 -2.500680  0.000000  0.000000
# 363                   R-HSA-69481 -0.777495 -2.504292  0.000000  0.000000
# 364                 R-HSA-6811434 -0.709747 -2.506408  0.000000  0.000000
# 365                   R-HSA-68886 -0.689979 -2.513021  0.000000  0.000000
# 366                 R-HSA-5693538 -0.729496 -2.517271  0.000000  0.000000
# 367                   R-HSA-73894 -0.656671 -2.522027  0.000000  0.000000
# 368                 R-HSA-5693567 -0.721099 -2.524847  0.000000  0.000000
#
#      geneset_size  matched_size  \
# 0              70            67
# 1             105           105
# 2              20            20
# 3              23            23
# 4              18            18
# 5              17            17
# 6              16            16
# 7              16            16
# 8              53            53
# 9              21            21
# 10             20            20
# 11             50            50
# 12             31            31
# 13             15            15
# 14             67            64
# 15             25            25
# 16             20            20
# 17             82            78
# 18             54            54
# 19             18            18
# 20             44            44
# 21             19            15
# 22             31            31
# 23             45            45
# 24             15            15
# 25            208           208
# 26             15            15
# 27             91            91
# 28             42            38
# 29             44            44
# ..            ...           ...
# 339           132           132
# 340           197           197
# 341           199           199
# 342            76            76
# 343           198           198
# 344           106           106
# 345            96            95
# 346           117           117
# 347            41            41
# 348           189           189
# 349            75            75
# 350            90            90
# 351            66            66
# 352           200           200
# 353           201           201
# 354            78            78
# 355           234           233
# 356           131           131
# 357           112           112
# 358            81            81
# 359           507           507
# 360           274           274
# 361           635           633
# 362           148           148
# 363           151           151
# 364           100           100
# 365           363           363
# 366           120           120
# 367           295           295
# 368           114           114
#
#                                                  genes  \
# 0    FMO2;ADH5;ADH1C;MAOA;ADH1B;GSTM2;ADH4;ADH1A;AL...
# 1    CYP2U1;FMO2;ADH5;ADH1C;ALDH1A1;CES2;AOC3;CYP11...
# 2    FGF1;FGF2;FGF7;FGF17;FGFBP2;FGF16;FGF8;FGF20;F...
# 3    FGF1;PIK3R1;FGF2;FGF7;PTPN11;FGF17;GAB1;FGF16;...
# 4    FGF1;FGF2;FGF7;FGF17;FGF16;FGF8;FGF20;FGF9;FGF...
# 5    FGF1;FGF2;FGF7;FGF17;FGF16;FGF8;FGF20;FGF9;FGF...
# 6    FGF1;KL;FGF2;FGF17;FGFR1;FGF8;FGF20;FGF9;FGF6;...
# 7    FGF1;KL;FGF2;FGF17;FGFR1;FGF8;FGF20;FGF9;FGF6;...
# 8    PDE2A;ADCY4;PDE1C;PDE7B;GRIN2B;PDE1A;PDE3B;PDE...
# 9    FGF1;KL;PIK3R1;FGF2;PTPN11;FGF17;GAB1;FGFR1;PI...
# 10   FGF1;PIK3R1;FGF2;KLB;PTPN11;FGF17;GAB1;FGF16;P...
# 351  POLK;WRN;ATM;RPS27A;RFC1;MRE11;RAD9B;KAT5;UBC;...
# 352  NDEL1;PAFAH1B1;DYNC1LI2;TUBB6;ANAPC4;PPP2R1B;C...
# 353  NDEL1;PAFAH1B1;DYNC1LI2;TUBB6;ANAPC4;PPP2R1B;C...
# 354  ABRAXAS1;HERC2;WRN;WEE1;ATM;MRE11;RAD9B;YWHAG;...
# 355  NMT2;CHMP3;UBAP1;FYN;NMT1;GTF2H1;ELMO1;TAF1;CC...
# 356  FYN;ELMO1;RPS27A;NUP54;RANBP2;CUL5;CCNT1;UBC;P...
# 357  NEK9;PPP2R1B;NEK7;PPP2CB;PRKCA;MCPH1;LPIN1;NUP...
# 358  ABRAXAS1;HERC2;WRN;ATM;RPS27A;MRE11;RAD9B;UIMC...
# 359  PPP1R12B;NDEL1;CDKN1C;TFDP2;NEK9;PAFAH1B1;RBL2...
# 360  NDEL1;PAFAH1B1;DYNC1LI2;ABRAXAS1;ANAPC4;PPP2R1...
# 361  CDC14B;PPP1R12B;NDEL1;CDKN1C;SYNE1;TFDP2;NEK9;...
# 362  ABRAXAS1;APBB1;POLK;HERC2;WRN;ABL1;ATM;RPS27A;...
# 363  ABRAXAS1;HERC2;WRN;WEE1;ATM;RPS27A;MRE11;RAD9B...
# 364  KIF26A;TUBB6;KIF25;KIF1C;COPZ2;TUBB2A;NBAS;KIF...
# 365  NDEL1;NEK9;PAFAH1B1;DYNC1LI2;PRKAR2B;TUBB6;ANA...
# 366  ABRAXAS1;POLK;HERC2;WRN;ABL1;ATM;RPS27A;RFC1;M...
# 367  REV3L;REV1;ABRAXAS1;FTO;XPA;XPC;APBB1;WDR48;PI...
# 368  ABRAXAS1;POLK;HERC2;WRN;ABL1;ATM;RPS27A;RFC1;M...
#
#                                            ledge_genes
# 0    FMO2;ADH5;ADH1C;MAOA;ADH1B;GSTM2;ADH4;ADH1A;AL...
# 1    CYP2U1;FMO2;ADH5;ADH1C;ALDH1A1;CES2;AOC3;CYP11...
# 2    FGF1;FGF2;FGF7;FGF17;FGFBP2;FGF16;FGF8;FGF20;FGF9
# 3    FGF1;PIK3R1;FGF2;FGF7;PTPN11;FGF17;GAB1;FGF16;...
# 4           FGF1;FGF2;FGF7;FGF17;FGF16;FGF8;FGF20;FGF9
# 5           FGF1;FGF2;FGF7;FGF17;FGF16;FGF8;FGF20;FGF9
# 6             FGF1;KL;FGF2;FGF17;FGFR1;FGF8;FGF20;FGF9
# 7             FGF1;KL;FGF2;FGF17;FGFR1;FGF8;FGF20;FGF9
# 8    PDE2A;ADCY4;PDE1C;PDE7B;GRIN2B;PDE1A;PDE3B;PDE...
# 9    FGF1;KL;PIK3R1;FGF2;PTPN11;FGF17;GAB1;FGFR1;PI...
# 10   FGF1;PIK3R1;FGF2;KLB;PTPN11;FGF17;GAB1;FGF16;P...
# 11   SPRY2;FGF1;KL;PIK3R1;FGF2;FLRT2;SOS1;PTPN11;CB...
# 12   SCN4B;SCN2B;SPTBN1;SCN3A;ANK2;SCN5A;SCN3B;SCN1...
# 353  PSMB1;VRK2;UBB;TUBAL3;PPP2R5D;ANAPC15;CENPQ;B9...
# 354  HUS1;H2BFS;HIST1H2BH;BRCC3;TOP3A;RNF8;NBN;RAD9...
# 355  XRCC6;NUP107;CCNK;PSMB6;VTA1;GTF2F1;LCK;GTF2F2...
# 356  PSMD6;BTRC;RAC1;TPR;NUP107;PSMB6;LCK;PSMB1;PAC...
# 357  HIST2H2AA3;H2BFS;PHF8;NUP58;NCAPH2;AAAS;SEH1L;...
# 358  HUS1;H2BFS;HIST1H2BH;BRCC3;TOP3A;RNF8;NBN;RAD9...
# 359  PPP2R5D;CEP41;HIST2H2AA3;ANAPC15;CEP78;SKP2;H2...
# 360  ANAPC15;HUS1;H2BFS;CENPQ;B9D2;PSMD5;PSMF1;PSMD...
# 361  ANAPC15;CEP78;SKP2;HUS1;H2BFS;HAUS7;CENPQ;ZBTB...
# 362  RAD51D;HUS1;H2BFS;KDM4A;HIST1H2BH;BRCC3;XRCC3;...
# 363  HUS1;H2BFS;PSMD5;PSMF1;PSMD3;PSMD9;HIST1H2BH;P...
# 364  KIF9;RAB1A;KIF3B;BNIP1;RAB1B;STX18;KIF4B;KIF21...
# 365  PPP2R5D;CEP41;HIST2H2AA3;ANAPC15;CEP78;H2BFS;H...
# 366  RAD51D;HUS1;H2BFS;HIST1H2BH;BRCC3;XRCC3;TOP3A;...
# 367  XRCC6;POLH;CUL4A;PARP2;INO80B;ALKBH2;ELL;ZBTB3...
# 368  RAD51D;HUS1;H2BFS;HIST1H2BH;BRCC3;XRCC3;TOP3A;...
#
# [369 rows x 10 columns]

# %%
b_kegg_df, b_reactome_df, b_wp_df, b_merge_df, b_merge_total_df = gsea_results_to_filtered_df(
    brca_dataset,
    kegg_manager=kegg_manager,
    reactome_manager=reactome_manager,
    wikipathways_manager=wikipathways_manager,
    p_value=0.05,
    absolute_nes_filter=2,
    geneset_set_filter_minimum_size=20,
    geneset_set_filter_maximum_size=None
)

# %%
type(b_merge_df)
# Out:
# pandas.core.frame.DataFrame

# %%
for elem in brca_merge_df.iloc[0]:
    print(elem)
# Out:
# Drug metabolism - cytochrome P450 - Homo sapiens (human)
# hsa00982
# 0.6063606475747181
# 2.3861782967785743
# 0.0
# 0.007033543887604562
# 70
# 67
# FMO2;ADH5;ADH1C;MAOA;ADH1B;GSTM2;ADH4;ADH1A;ALDH1A3;AOX1;ADH6;MGST1;HPGDS;CYP3A4;FMO4;FMO1;CYP1A2;MAOB;GSTM5;CYP3A5;GSTK1;GSTT2;GSTA4;UGT2B28;GSTP1;GSTM4;GSTT2B;MGST3;UGT2B15;FMO5;MGST2;GSTA1;CYP2C9;ADH7;CYP2D7;ALDH3A1;GSTM1;UGT2B7;CYP2C19;UGT2B11;UGT1A9;UGT1A8;UGT1A7;FMO3;UGT2A1;CYP2E1;UGT1A4;UGT1A10;UGT1A3;GSTO2;UGT1A1;CYP2D6;UGT1A6;CYP2B6;GSTA2;UGT2B10;GSTA5;UGT2B4;UGT2A3;CYP2C8;ALDH3B2;CYP2A6;UGT2B17;GSTA3;GSTM3;ALDH3B1;GSTO1
# FMO2;ADH5;ADH1C;MAOA;ADH1B;GSTM2;ADH4;ADH1A;ALDH1A3;AOX1;ADH6;MGST1;HPGDS;CYP3A4;FMO4;FMO1;CYP1A2;MAOB;GSTM5;CYP3A5;GSTK1;GSTT2

# %% [markdown]
# ### BRCA Dataset comparison
#
# *Custom filter to return only pathways with over 20 genes

# %% [markdown]
# |Pathway|KEGG NES (match size)|Reactome NES (match size)|WikiPathways NES (match size)|Merged NES (match size)|Molecular entities|Pathway Description
# |------|------|------|------|------|------|------|
# |Drug metabolism - cytochrome P450 - Homo sapiens (human)|2.392575 (67)|-|-|2.386178 (67)|ALDH1A3: Association with cancer development, progression and prognosis|loss of retinoid activity present in HCC cell lines, decreased storage of hepatic retinoid, aberrant retinoid signaling in patients with cirrhosis and HCC (PMID:26311412)

# %% [markdown]
# ### LIHC Dataset comparison

# %%
lihc_merge_df
# Out:
#                                           pathway_name  \
# 0            Retinol metabolism - Homo sapiens (human)
# 1                                 Tamoxifen metabolism
# 2             Complement cascade|Complement Activation
# 3          Histidine metabolism - Homo sapiens (human)
# 4                              Human Complement System
# 5                                          Xenobiotics
# 6    Complement and coagulation cascades - Homo sap...
# 7          Parkin-Ubiquitin Proteasomal System pathway
# 8                           G1 to S cell cycle control
# 9    Transport of Mature mRNA derived from an Intro...
# 10   Cooperation of PDCL (PhLP1) and TRiC/CCT in G-...
# 11                                   Signalling to RAS
# 12                               DNA strand elongation
# 13                           Apoptotic execution phase
# 14   Mitophagy - animal - Homo sapiens (human)|Mito...
# 15    Insulin signaling pathway - Homo sapiens (human)
# 16                                 Signaling by NOTCH3
# 17   Follicle Stimulating Hormone (FSH) signaling p...
# 18        APC/C:Cdc20 mediated degradation of Cyclin B
# 19        Negative regulators of DDX58/IFIH1 signaling
# 20                                Protein localization
# 21                     Interleukin-12 family signaling
# 22                  Shigellosis - Homo sapiens (human)
# 23    TP53 Regulates Transcription of Cell Cycle Genes
# 24                      Pink/Parkin Mediated Mitophagy
# 25   Anchoring of the basal body to the plasma memb...
# 26                       Rab regulation of trafficking
# 27                     PKMTs methylate histone lysines
# 28   Major pathway of rRNA processing in the nucleo...
# 29                            Lagging Strand Synthesis
# ..                                                 ...
# 424                             Cell Cycle Checkpoints
# 425                   Nonalcoholic fatty liver disease
# 426                                    tRNA processing
# 427                                 Infectious disease
# 428  Regulation of mRNA stability by proteins that ...
# 429                                            Disease
# 430                       Cellular responses to stress
# 431                 Spliceosome - Homo sapiens (human)
# 432                        Regulation of TP53 Activity
# 433                            Dual incision in TC-NER
# 434             ABC-family proteins mediated transport
# 435  Notch signaling pathway - Homo sapiens (human)...
# 436  Protein processing in endoplasmic reticulum - ...
# 437                            Interleukin-1 signaling
# 438             Cellular responses to external stimuli
# 439                     IRE1alpha activates chaperones
# 440                                      HIV Infection
# 441  Global Genome Nucleotide Excision Repair (GG-NER)
# 442                  XBP1(S) activates chaperone genes
# 443                    Unfolded Protein Response (UPR)
# 444  Transcription-Coupled Nucleotide Excision Repa...
# 445                                   Deubiquitination
# 446                                  Metabolism of RNA
# 447            Post-translational protein modification
# 448                                         DNA Repair
# 449  Nucleotide excision repair - Homo sapiens (hum...
# 450  Pyrimidine metabolism - Homo sapiens (human)|P...
# 451                                        Neddylation
# 452                 Transcriptional Regulation by TP53
# 453                             Metabolism of proteins
#
#                             pathway_id        es       nes      pval  \
# 0                             hsa00830  0.675921  2.230719  0.000000
# 1                                WP691  0.808853  2.100633  0.001385
# 2                   R-HSA-166658|WP545  0.677238  2.078727  0.006983
# 3                             hsa00340  0.725864  2.077178  0.003989
# 4                               WP2806  0.567516  2.046771  0.000000
# 5                         R-HSA-211981  0.712671  2.040787  0.004178
# 6                       hsa04610|WP558  0.658520  2.028936  0.001244
# 7                               WP2359 -0.608084 -2.001458  0.000000
# 8                                 WP45 -0.665122 -2.001925  0.002378
# 9                         R-HSA-159236 -0.718337 -2.002650  0.000000
# 10                       R-HSA-6814122 -0.605896 -2.003563  0.003315
# 11                        R-HSA-167044 -0.689182 -2.003568  0.000000
# 12                         R-HSA-69190 -0.841401 -2.005491  0.000000
# 13                         R-HSA-75153 -0.624897 -2.005739  0.000000
# 14              hsa04137|R-HSA-5205647 -0.574563 -2.006887  0.001218
# 15                            hsa04910 -0.506275 -2.007319  0.000000
# 16                       R-HSA-9012852 -0.615287 -2.008570  0.000000
# 17                              WP2035 -0.631063 -2.011643  0.000000
# 18                        R-HSA-174048 -0.762784 -2.012243  0.000000
# 19                        R-HSA-936440 -0.642538 -2.013298  0.001218
# 20                       R-HSA-9609507 -0.511301 -2.013718  0.002421
# 21                        R-HSA-447115 -0.592074 -2.014035  0.000000
# 22                            hsa05131 -0.632844 -2.014232  0.000000
# 23                       R-HSA-6791312 -0.664963 -2.015546  0.000000
# 24                       R-HSA-5205685 -0.680698 -2.016733  0.000000
# 25                       R-HSA-5620912 -0.678692 -2.018811  0.000000
# 26                       R-HSA-9007101 -0.594264 -2.019157  0.000000
# 27                       R-HSA-3214841 -0.686331 -2.019366  0.000000
# 28                       R-HSA-6791226 -0.712591 -2.020186  0.004902
# 29                         R-HSA-69186 -0.842365 -2.022612  0.000000
# ..                                 ...       ...       ...       ...
# 424                        R-HSA-69620 -0.723968 -2.316578  0.000000
# 425                             WP4396 -0.600428 -2.321427  0.000000
# 426                        R-HSA-72306 -0.732556 -2.321805  0.000000
# 427                      R-HSA-5663205 -0.662127 -2.322634  0.000000
# 428                       R-HSA-450531 -0.724431 -2.322819  0.000000
# 429                      R-HSA-1643685 -0.533213 -2.323109  0.000000
# 430                      R-HSA-2262752 -0.608479 -2.323299  0.000000
# 431                           hsa03040 -0.757487 -2.323666  0.000000
# 432                      R-HSA-5633007 -0.690569 -2.324482  0.000000
# 433                      R-HSA-6782135 -0.734909 -2.324765  0.000000
# 434                       R-HSA-382556 -0.621824 -2.326593  0.000000
# 435  hsa04330|R-HSA-157118|WP61|WP3845 -0.602113 -2.329441  0.000000
# 436                           hsa04141 -0.630912 -2.331484  0.000000
# 437                      R-HSA-9020702 -0.651111 -2.331837  0.000000
# 438                      R-HSA-8953897 -0.605052 -2.338981  0.000000
# 439                       R-HSA-381070 -0.725351 -2.345130  0.000000
# 440                       R-HSA-162906 -0.681412 -2.346778  0.000000
# 441                      R-HSA-5696399 -0.747311 -2.347016  0.000000
# 442                       R-HSA-381038 -0.728324 -2.348372  0.000000
# 443                       R-HSA-381119 -0.681669 -2.361580  0.000000
# 444                      R-HSA-6781827 -0.742002 -2.373443  0.000000
# 445                      R-HSA-5688426 -0.643291 -2.383639  0.000000
# 446                      R-HSA-8953854 -0.720317 -2.384230  0.000000
# 447                       R-HSA-597592 -0.571520 -2.386619  0.000000
# 448                        R-HSA-73894 -0.701507 -2.386707  0.000000
# 449             hsa03420|R-HSA-5696398 -0.733558 -2.398289  0.000000
# 450                    hsa00240|WP4022 -0.669636 -2.423273  0.000000
# 451                      R-HSA-8951664 -0.632517 -2.435475  0.000000
# 452                      R-HSA-3700989 -0.655891 -2.437719  0.000000
# 453                       R-HSA-392499 -0.592950 -2.525133  0.000000
#
#           fdr  geneset_size  matched_size  \
# 0    0.007285            67            66
# 1    0.026473            21            21
# 2    0.022636           121           119
# 3    0.017432            23            23
# 4    0.020710            99            97
# 5    0.018755            24            24
# 6    0.019030            82            81
# 7    0.002027            70            70
# 8    0.002021            64            64
# 9    0.001990            74            72
# 10   0.001972            42            42
# 11   0.001974            20            20
# 12   0.001927            32            32
# 13   0.001916            52            52
# 14   0.001885            79            78
# 15   0.001882           137           137
# 16   0.001868            49            49
# 17   0.001767            27            27
# 18   0.001753            23            23
# 19   0.001725            34            34
# 20   0.001722           128           127
# 21   0.001719            56            55
# 22   0.001721            65            65
# 23   0.001686            49            49
# 24   0.001644            22            21
# 25   0.001604            97            97
# 26   0.001599           122           122
# 27   0.001600            47            47
# 28   0.001588           183           183
# 29   0.001536            20            20
# ..        ...           ...           ...
# 424  0.000000           274           273
# 425  0.000000           159           149
# 426  0.000000           108           108
# 427  0.000000           382           380
# 428  0.000000            87            87
# 429  0.000000          1064          1057
# 430  0.000000           400           399
# 431  0.000000           134           134
# 432  0.000000           160           160
# 433  0.000000            65            65
# 434  0.000000           103           103
# 435  0.000000           240           239
# 436  0.000000           165           163
# 437  0.000000           102           102
# 438  0.000000           477           475
# 439  0.000000            57            56
# 440  0.000000           234           232
# 441  0.000000            84            84
# 442  0.000000            55            54
# 443  0.000000            95            94
# 444  0.000000            78            78
# 445  0.000000           282           265
# 446  0.000000           667           665
# 447  0.000000          1404          1381
# 448  0.000000           295           295
# 449  0.000000           114           113
# 450  0.000000           102           100
# 451  0.000000           235           233
# 452  0.000000           365           360
# 453  0.000000          1998          1971
#
#                                                  genes  \
# 0    CYP2C8;CYP4A11;LRAT;CYP4A22;ADH4;RDH16;UGT2B7;...
# 1    CYP2C8;UGT2B7;CYP2C9;CYP1A2;CYP2C19;CYP2E1;SUL...
# 2    FCN2;COLEC10;CFP;FCN3;C1R;C8A;C6;C9;C8B;MASP1;...
# 3    ALDH2;CNDP1;UROC1;ASPA;FTCD;AMDHD1;ALDH1B1;MAO...
# 4    FCN2;CLEC4M;CFP;C1R;C8A;C6;ALB;C9;PLG;MASP1;KL...
# 5    CYP2C8;CYP2C9;CYP1A2;CYP2B6;CYP2J2;CYP2C19;CYP...
# 6    C1R;C8A;C6;C9;PLG;C8B;MASP1;F9;KLKB1;C1S;FGB;S...
# 7    TUBB1;UBE2L6;SNCA;CASP1;HSPA6;UBE2G1;TUBB6;GPR...
# 8    WEE1;MYC;GADD45A;CREB3L3;CDKN1A;CCND1;CCNA1;CC...
# 9    CDC40;SRSF5;NUP88;FYTTD1;RANBP2;NUP98;U2AF1;NU...
# 10   GNAO1;CCT6B;RGS7;GNB4;GNG2;GNAT2;GNGT2;GNG12;R...
# 11   NGF;RALGDS;NTRK1;KRAS;SHC2;RALB;MAPK13;SOS1;SH...
# 12   POLD2;POLD4;GINS4;RPA1;POLD3;RPA3;RPA2;DNA2;MC...
# 13   TJP2;SATB1;BMX;DSG1;CASP7;DSG3;PRKCQ;PKP1;CDH1...
# 14   JUN;GABARAPL1;PINK1;CITED2;TBC1D15;BNIP3L;MFN2...
# 15   GYS2;FBP1;PCK1;SOCS2;FOXO1;PCK2;PPP1R3B;MAP2K1...
# 16   HEY2;HES1;PTCRA;KAT2B;IKZF1;EGFR;FABP7;PBX1;ST...
# 17   FOXO1;SGK1;FSHR;FSHB;AREG;AKT1;BDNF;CGA;CYP19A...
# 18   UBB;ANAPC16;CDC26;ANAPC10;UBC;UBE2D1;UBA52;RPS...
# 19   RNF125;HERC5;ISG15;ITCH;UBE2L6;IFIH1;DDX58;RNF...
# 20   HAO2;HAO1;ACAA1;EPHX2;HMGCL;MLYCD;LDHD;CAT;FXN...
# 21   IL6ST;IL27;IL10;GSTA2;STAT3;EBI3;SOD1;SOD2;SER...
# 22   HCLS1;NFKBIA;CRK;CXCL8;PFN3;U2AF1L5;NFKB1;MAPK...
# 23   PLK3;GADD45A;RBL2;PLK2;CDKN1A;CCNA1;BTG2;CNOT6...
# 24   PINK1;MFN2;MAP1LC3A;UBB;MAP1LC3B;PRKN;ATG5;UBC...
# 25   PRKAR2B;AKAP9;FGFR1OP;HAUS7;PCM1;TUBA1A;TUBB4A...
# 26   RAB33B;RAB27A;RAB39A;DENND4A;TBC1D15;TBC1D3;TR...
# 27   HIST2H3A;SETD7;NFKB1;PRDM9;ASH2L;SETD3;KMT5B;H...
# 28   RCL1;UTP3;UTP14C;PWP2;DDX21;RPS4Y2;EXOSC6;RPP1...
# 29   POLD2;POLD4;RPA1;POLD3;RPA3;RPA2;DNA2;RFC3;POL...
# ..                                                 ...
# 424  WEE1;NDEL1;PPP2CB;CDKN1A;CCNA1;RNF168;PSMA8;PS...
# 425  JUN;SOCS3;CYP2E1;SDHB;SDHD;IL1B;PRKAG2;COX6A2;...
# 426  NSUN6;HSD17B10;TRMT11;TRMT9B;PUS3;RPP14;TRMT10...
# 427  CD4;ANTXR2;MAP2K1;MAP2K3;FYN;MAP2K4;HBEGF;ELOA...
# 428  ZFP36;ZFP36L1;TNFSF13;AKT1;XRN1;PSMA8;PSMA2;UB...
# 429  ADAMTS13;CFP;LRAT;GYS2;ALB;MAT1A;ESR1;GNE;FGB;...
# 430  FOS;CAT;ETS2;NR3C2;JUN;ID1;MAP2K3;CAMK2B;AR;CI...
# 431  SRSF8;RBMXL1;RBMXL2;RBMXL3;CDC40;ISY1-RAB43;HS...
# 432  PLK3;PRKAG2;SGK1;PPP2CB;PRR5;USP2;CCNA1;POU4F2...
# 433  CCNH;POLR2F;UBB;ERCC4;POLR2A;GTF2H2;POLE4;ERCC...
# 434  ERLIN1;APOA1;ABCA8;ABCC9;ABCA6;PEX3;ABCD3;ABCA...
# 435  ST3GAL6;DTX1;JUN;NCOR1;MYC;HEY2;FHL1;HES1;GATA...
# 436  MAN1C1;MAN1A1;SEC62;SEC24B;NFE2L2;LMAN1;EDEM1;...
# 437  IL1RAP;S100A12;IL1RN;MAP2K1;MYD88;NKIRAS1;IL1B...
# 438  FOS;CAT;ETS2;MT2A;MT1E;MT1X;MT1F;NR3C2;JUN;ID1...
# 439  SEC62;EDEM1;PDIA5;ACADVL;DNAJB9;SRPRA;ERN1;SEC...
# 440  CD4;FYN;ELOA3D;HCK;DOCK2;CD247;CDK9;CCR5;CXCR4...
# 441  CCNH;UBB;DDB2;ERCC4;XPC;GTF2H2;POLE4;RAD23B;RN...
# 442  SEC62;EDEM1;PDIA5;ACADVL;DNAJB9;SRPRA;SEC61A2;...
# 443  ATF3;IGFBP1;SEC62;CREB3L3;EDEM1;CCL2;PDIA5;ACA...
# 444  CCNH;POLR2F;UBB;ERCC4;POLR2A;ELL;GTF2H2;POLE4;...
# 445  ESR1;AR;IL33;MYC;ADRB2;GATA3;USP18;NLRP3;USP12...
# 446  ZFP36;RCL1;NSUN6;ZFP36L1;A1CF;APOBEC3A;GSPT2;P...
# 447  ADAMTS13;CFP;ALB;F9;ESR1;GNE;IGFBP3;SOCS2;PROS...
# 448  FANCC;EYA2;MGMT;ISG15;UBE2L6;USP43;CCNA1;RCHY1...
# 449  BIVM-ERCC5;CCNH;POLR2F;UBB;DDB2;ERCC4;POLR2A;E...
# 450  DHODH;DPYS;CDA;UPB1;ENPP1;DPYD;ENTPD5;NT5C1B;P...
# 451  SOCS2;DCUN1D3;SPSB4;SOCS3;KLHL2;SOCS6;DCAF11;C...
# 452  STEAP3;IGFBP3;FOS;GLS2;JUN;PLK3;PRKAG2;GADD45A...
# 453  ADAMTS13;CFP;ALB;PLG;F9;ESR1;CLTRN;GNE;IGFALS;...
#
#                                            ledge_genes
# 0    CYP2C8;CYP4A11;LRAT;CYP4A22;ADH4;RDH16;UGT2B7;...
# 1    CYP2C8;UGT2B7;CYP2C9;CYP1A2;CYP2C19;CYP2E1;SUL...
# 2    FCN2;COLEC10;CFP;FCN3;C1R;C8A;C6;C9;C8B;MASP1;...
# 3    ALDH2;CNDP1;UROC1;ASPA;FTCD;AMDHD1;ALDH1B1;MAO...
# 4    FCN2;CLEC4M;CFP;C1R;C8A;C6;ALB;C9;PLG;MASP1;KL...
# 430  ANAPC16;HSPA8;TP53;HIST1H2AJ;CBX6;NUP50;HIST1H...
# 431  CTNNBL1;LSM6;BCAS2;SMNDC1;SNRNP40;SRSF4;AQR;SR...
# 432  RAD9B;GATAD2A;UBC;PPP1R13L;ATRIP;PPP1R13B;TAF3...
# 433  POLK;XPA;ZNF830;POLR2J;UBC;POLD2;POLR2I;POLD4;...
# 434  PSMB8;ABCA2;ABCA5;PSMD12;EIF2S1;UBC;ABCC4;KCNJ...
# 435  TFDP1;HIST1H2AB;MAMLD1;EP300;ADAM17;SPEN;HIST1...
# 436  NGLY1;EIF2S1;ERO1A;EDEM3;ATXN3;UBE2D1;ATF4;OS9...
# 437  SQSTM1;PSMC1;PSMB1;IRAK4;HMGB1;AGER;RIPK2;IKBK...
# 438  HSPA1A;CHMP2B;ANAPC16;HSPA8;TP53;HIST1H2AJ;CBX...
# 439  PLA2G4B;DDX11;EXTL3;SERP1;WIPI1;TSPYL2;CTDSP2;...
# 440  CCNT2;CCNT1;ELOB;PSIP1;PACS1;PSMC1;PSMB1;TAF9B...
# 441  ACTB;POLK;XPA;USP45;UBC;POLD2;INO80D;POLD4;CUL...
# 442  PLA2G4B;DDX11;EXTL3;SERP1;WIPI1;TSPYL2;CTDSP2;...
# 443  PLA2G4B;DDX11;EXTL3;SERP1;EIF2S1;WIPI1;ATF4;TS...
# 444  POLK;XPA;ZNF830;POLR2J;UBC;POLD2;POLR2I;POLD4;...
# 445  APC;MYSM1;HIST1H2BO;PSMB6;TADA2B;SMAD4;TP53;HI...
# 446  POLR2I;APOBEC3B;RPL3;CWC25;PCF11;ETF1;FBL;NOB1...
# 447  COMMD9;F5;MAN2A1;EP300;ASB7;MIA3;PIGA;KIN;SSPO...
# 448  POLB;HIST1H2BD;ACTB;POLK;XPA;ZNF830;USP45;RAD9...
# 449  ACTB;POLK;XPA;ZNF830;USP45;POLR2J;UBC;POLD2;PO...
# 450  POLR2J;POLD2;POLR2I;AK9;NT5C3A;POLD4;RRM2B;TWI...
# 451  COMMD9;ASB7;DCAF5;DCAF10;PSMB6;FEM1A;FBXO31;KL...
# 452  BRD1;NDRG1;CNOT1;GSR;CDKN1B;LAMTOR3;ING2;CREBB...
# 453  COMMD9;RPL34;F5;MAN2A1;EP300;ASB7;MIA3;PIGA;NA...
#
# [454 rows x 10 columns]

# %% [markdown]
# |Pathway Name|KEGG NES (match size)|Reactome NES (match size)|WikiPathways NES (match size)|Merged NES (match size)|Molecular entities|Pathway Description
# |------|------|------|------|------|------|------|
# |Retinol metabolism - Homo sapiens (human)|2.133740 (66)|-|-|2.230719 (66)|CYP2A6/CYP2C8: Down-regulation of gene leads to worse overall survival from hepatocellular carcinoma (HCC) (PMID:30148168); ADH4: Prognostic marker of liver cancer (PMID:22147505); UGT2B7: regulated by specific miRNA which control its expression in cancer and/or normal liver cells (PMID:28389526)|loss of retinoid activity present in HCC cell lines, decreased storage of hepatic retinoid, aberrant retinoid signaling in patients with cirrhosis and HCC (PMID:26311412)
# |Tamoxifen metabolism|-|-|2.058462 (21)|2.100633 (21)|CYP2A6/CYP2C8: Down-regulation of gene leads to worse overall survival from hepatocellular carcinoma (HCC) (PMID:30148168); UGT2B7: regulated my specific miRNA which control its expression in cancer and/or normal liver cells (PMID:28389526); SULT1A1: potentially altered in HCC development (PMID:16517757)|Tamoxifen metabolism in the liver; Tamoxifen treatment (commonly for breast cancer) associated with a side effect of an increased risk of the development of nonalcoholic fatty liver (steatosis)
# |Complement cascade/Complement Activation|-|2.083848 (119)|2.066553 (22)|2.078727 (119)|FCN2: Potential prognostic marker of HCC (PMID:27177473); COLEC10: decreased expression may predict poor overall survival in HCC patients| Complement activation can increase tumor growth and metastasis

# %% [markdown]
# Liver Hepatocellular Carcinoma (LIHC) GSEA results for pathways from three major databases (KEGG, Reactome and WikiPathways) and one merged resource (PathwayForte) were filtered by a p-value of 0.05%, a minimum gene set size of 10 and normalized enrichment scores greater than 2 or less than -2. For the PathwayForte resource, the filtering revealed 486 pathways, of which the majority derived from Reactome (~76%), ~13% derived from KEGG, ~5% from WikiPathways and the remaining ~7% from two or more databases.
#
# The top ranking pathway returned for the merged resource was 'Retinol metabolism - Homo Sapiens (human)'. An in-depth analysis of genes involved in this pathway revealed genes which have been previously studied for their role in the development of hepatocellular carcinoma (HCC). These include CYP2A6/CYP2C8 (down-regulation of this gene leads to worse overall survival from hepatocellular carcinoma (HCC)), ADH4 (a prognostic marker of liver cancer) and UGT2B7  (regulated by a specific miRNA which control its expression in cancer and/or normal liver cells). Among the top 3 ranked pathways, we find an equivalent pathway (i.e., the combination of complement cascade and complement activation from Reactome and WikiPathways, respectively) which is evidenced to increase tumor growth and metastasis. FCN2 (a potential prognostic marker of HCC) and  COLEC10 (decreased expression of which may predict poor overall survival in HCC patients).
#
#
# For the top 486 ranked pathways in the merged LIHC dataset:
# 12.55% are from KEGG
# 76.13% are from Reactome
# 4.73% are from WikiPathways
# 6.58% are a combination of 2 or more databases

# %% [markdown]
# Plot how many pairwise pathways with mappings exist versus how many are expected

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15,10))
fig.suptitle('Recovered Versus Un-Recovered Mappings for Pathway Resources', fontsize=22)

N = 7
index = np.arange(N)
bar_width = 0.35
opacity = 0.8

pairings = ('KEGG-Reactome', 
 'KEGG-WikiPathways', 
 'Reactome-KEGG', 
 'Reactome-WikiPathways',
 'WikiPathways-KEGG', 
 'WikiPathways-Reactome',
 'Merged Dataset'
)
label_font = {'size': 16}


plt.subplot(2, 2, 1)
actual_vals = list(brca_actual_dict.values())
expected_vals = list(brca_expected_dict.values())
difference = [x - y for x, y in zip(expected_vals, actual_vals)]

p1 = plt.bar(ind, actual_vals, width,alpha=opacity, color='#88b4d3',label='Recovered')
p2 = plt.bar(ind, difference, width, bottom=actual_vals, alpha=opacity, color='#f9b880',label='Un-Recovered')

plt.title('BRCA Dataset', fontsize=16)
plt.ylabel('Number of Mappings', fontdict=label_font)
plt.xticks(index, pairings)
plt.ylim(0,40)
plt.legend(prop={'size':13},loc=2)


plt.subplot(2, 2, 2)
actual_vals = list(kirc_actual_dict.values())
expected_vals = list(kirc_expected_dict.values())
difference = [x - y for x, y in zip(expected_vals, actual_vals)]

p1 = plt.bar(ind, actual_vals, width,alpha=opacity, color='#88b4d3',label='Recovered')
p2 = plt.bar(ind, difference, width, bottom=actual_vals, alpha=opacity, color='#f9b880',label='Un-Recovered')

plt.title('KIRC Dataset', fontsize=16)
plt.xticks(index, pairings)
plt.ylim(0,12)
plt.legend(prop={'size':13},loc=2)

plt.subplot(2, 2, 3)
actual_vals = list(lihc_actual_dict.values())
expected_vals = list(lihc_expected_dict.values())
difference = [x - y for x, y in zip(expected_vals, actual_vals)]

p1 = plt.bar(ind, actual_vals, width,alpha=opacity, color='#88b4d3',label='Recovered')
p2 = plt.bar(ind, difference, width, bottom=actual_vals, alpha=opacity, color='#f9b880',label='Un-Recovered')

plt.title('LIHC Dataset', fontsize=16)
plt.ylabel('Number of Mappings', fontdict=label_font)
plt.xlabel('Contributing Resource', fontdict=label_font)
plt.xticks(index, pairings)
plt.ylim(0,40)
plt.legend(prop={'size':13},loc=2)

plt.subplot(2, 2, 4)
actual_vals = list(prad_actual_dict.values())
expected_vals = list(prad_expected_dict.values())
difference = [x - y for x, y in zip(expected_vals, actual_vals)]

p1 = plt.bar(ind, actual_vals, width,alpha=opacity, color='#88b4d3',label='Recovered')
p2 = plt.bar(ind, difference, width, bottom=actual_vals, alpha=opacity, color='#f9b880',label='Un-Recovered')

plt.title('PRAD Dataset', fontsize=16)
plt.xlabel('Contributing Resource', fontdict=label_font)
plt.ylim(0,13)
plt.xticks(index, pairings)
plt.legend(prop={'size':13},loc=2)

fig.autofmt_xdate()
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('pairwise_mappings.png',dpi=250)
plt.show()

# %% [markdown]
# This figure depicts the number of pathways which are anticipated to be seen in one database contingent on their being present in a second database as these sets of pathways are defined as equivalent across databases. These expected pathways between pairwise sets of databases (blue) and the number of pairwise mappings which actually exist (orange) are plotted for four TCGA datasets (i.e., BRCA, LIHC, KIRC and PRAD). The upper two subplots in the figure (i.e., BRCA and LIHC) are larger pathways and correspondingly contain a much greater proportion of genes while the lower two (i.e., KIRC and PRAD) contain a fewer number. As such, the number of equivalent pathway mappings in the lower datasets is lower than the former.
#
# In the figure attached, you can see the number of pathways which are expected to be enriched in one database because they are present in a second database as these pairs of pathways are defined as equivalent across databases (e.g., if we see apoptosis is significant in gsea results for KEGG for breast cancer and we know apoptosis is also a pathway in Reactome, we should also see it in gsea results for Reactome). As can be seen in the figure,  while a single database captures some but a limited number of equivalent pathways, the merged dataset includes most of the pathways which are expected

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15,10))
fig.suptitle('Actual Versus Expected Mappings for Mapping Resources', fontsize=20)

index = np.arange(7)
bar_width = 0.35
opacity = 0.8

pairings = ('KEGG-Reactome', 
 'KEGG-WikiPathways', 
 'Reactome-KEGG', 
 'Reactome-WikiPathways',
 'WikiPathways-KEGG', 
 'WikiPathways-Reactome',
 'Merged Dataset'
)
label_font = {'size': 16}

plt.subplot(2, 2, 1)
plt.bar(
    index, 
    list(brca_actual_dict.values()), 
    bar_width,
    alpha=opacity,
    color='#f9b880',
    label='Actual'
)
plt.bar(
    index + bar_width, 
    list(brca_expected_dict.values()), 
    bar_width,
    alpha=opacity,
    color='#88b4d3',
    label='Expected'
)
plt.title('BRCA dataset', fontsize=16)
plt.ylabel('Number of Mappings', fontdict=label_font)
plt.xlabel('Contributing Resource', fontdict=label_font)
plt.xticks(index + bar_width/2, pairings)
plt.ylim(0,40)
plt.legend(prop={'size':13},loc=2)

plt.subplot(2, 2, 2)
plt.bar(
    index, 
    list(kirc_actual_dict.values()), 
    bar_width,
    alpha=opacity,
    color='#f9b880',
    label='Actual'
)
plt.bar(
    index + bar_width, 
    list(kirc_expected_dict.values()), 
    bar_width,
    alpha=opacity,
    color='#88b4d3',
    label='Expected'
)
plt.title('KIRC dataset', fontsize=16)
plt.ylabel('Number of Mappings', fontdict=label_font)
plt.xlabel('Contributing Resource', fontdict=label_font)
plt.xticks(index + bar_width/2, pairings)
plt.ylim(0,13)
plt.legend(prop={'size':13},loc=2)

plt.subplot(2, 2, 3)
plt.bar(
    index, 
    list(lihc_actual_dict.values()), 
    bar_width,
    alpha=opacity,
    color='#f9b880',
    label='Actual'
)
plt.bar(
    index + bar_width, 
    list(lihc_expected_dict.values()), 
    bar_width,
    alpha=opacity,
    color='#88b4d3',
    label='Expected'
)
plt.title('LIHC dataset', fontsize=16)
plt.xlabel('Contributing Resource', fontdict=label_font)
plt.xticks(index + bar_width/2, pairings)
plt.ylim(0,40)
plt.legend(prop={'size':13},loc=2)

plt.subplot(2, 2, 4)
plt.bar(
    index, 
    list(prad_actual_dict.values()), 
    bar_width,
    alpha=opacity,
    color='#f9b880',
    label='Actual'
)
plt.bar(
    index + bar_width, 
    list(prad_expected_dict.values()), 
    bar_width,
    alpha=opacity,
    color='#88b4d3',
    label='Expected'
)
plt.title('PRAD dataset', fontsize=16)
plt.xlabel('Contributing Resource', fontdict=label_font)
plt.xticks(index + bar_width/2, pairings)
plt.ylim(0,13)
plt.legend(prop={'size':13},loc=2)

fig.autofmt_xdate()
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('pairwise_mappings.png',dpi=500)
plt.show()

# %%
gsea_merge_statistics(brca_merge_df, 'BRCA')
# Out:
# For the top 384 ranked pathways in the merged BRCA dataset:
# 9.38% are from KEGG
# 78.39% are from Reactome
# 8.33% are from WikiPathways
# 3.91% are a combination of 2 or more databases

# %%
gsea_merge_statistics(lihc_merge_df, 'LIHC')
# Out:
# For the top 486 ranked pathways in the merged LIHC dataset:
# 12.55% are from KEGG
# 76.13% are from Reactome
# 4.73% are from WikiPathways
# 6.58% are a combination of 2 or more databases

# %%
gsea_merge_statistics(kirc_merge_df, 'KIRC')
# Out:
# For the top 68 ranked pathways in the merged KIRC dataset:
# 48.53% are from KEGG
# 30.88% are from Reactome
# 11.76% are from WikiPathways
# 8.82% are a combination of 2 or more databases

# %%
gsea_merge_statistics(prad_merge_df, 'PRAD')
# Out:
# For the top 74 ranked pathways in the merged PRAD dataset:
# 31.08% are from KEGG
# 37.84% are from Reactome
# 24.32% are from WikiPathways
# 6.76% are a combination of 2 or more databases

# %%
#TODO count for num sig pathways and how many of those are equivalent
